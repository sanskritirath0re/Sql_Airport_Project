# %%
pip install dash sqlalchemy pymysql pandas plotly
# Out:
# Requirement already satisfied: dash in c:\users\sansk\appdata\roaming\python\python312\site-packages (2.18.1)
# Requirement already satisfied: sqlalchemy in c:\users\sansk\anaconda3\lib\site-packages (2.0.30)
# Requirement already satisfied: pymysql in c:\users\sansk\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: pandas in c:\users\sansk\appdata\roaming\python\python312\site-packages (2.2.3)
# Requirement already satisfied: plotly in c:\users\sansk\appdata\roaming\python\python312\site-packages (5.24.1)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\sansk\appdata\roaming\python\python312\site-packages (from dash) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\sansk\appdata\roaming\python\python312\site-packages (from dash) (3.0.4)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\sansk\appdata\roaming\python\python312\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\sansk\appdata\roaming\python\python312\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\sansk\appdata\roaming\python\python312\site-packages (from dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\sansk\appdata\roaming\python\python312\site-packages (from dash) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\sansk\appdata\roaming\python\python312\site-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in c:\users\sansk\appdata\roaming\python\python312\site-packages (from dash) (2.32.3)
# Requirement already satisfied: retrying in c:\users\sansk\appdata\roaming\python\python312\site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\sansk\appdata\roaming\python\python312\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\sansk\appdata\roaming\python\python312\site-packages (from dash) (75.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sansk\anaconda3\lib\site-packages (from sqlalchemy) (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sansk\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sansk\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sansk\appdata\roaming\python\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sansk\appdata\roaming\python\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\sansk\anaconda3\lib\site-packages (from plotly) (8.2.2)
# Requirement already satisfied: packaging in c:\users\sansk\appdata\roaming\python\python312\site-packages (from plotly) (24.2)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\sansk\appdata\roaming\python\python312\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\sansk\appdata\roaming\python\python312\site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\sansk\appdata\roaming\python\python312\site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\sansk\appdata\roaming\python\python312\site-packages (from Flask<3.1,>=1.0.4->dash) (1.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\sansk\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\sansk\appdata\roaming\python\python312\site-packages (from Werkzeug<3.1->dash) (2.1.5)
# Requirement already satisfied: zipp>=3.20 in c:\users\sansk\appdata\roaming\python\python312\site-packages (from importlib-metadata->dash) (3.20.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sansk\appdata\roaming\python\python312\site-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sansk\appdata\roaming\python\python312\site-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sansk\appdata\roaming\python\python312\site-packages (from requests->dash) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sansk\appdata\roaming\python\python312\site-packages (from requests->dash) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\sansk\appdata\roaming\python\python312\site-packages (from click>=8.1.3->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\users\sansk\anaconda3\lib\site-packages\fault_detection-0.0.1-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
import pandas as pd
from sqlalchemy import create_engine

##DB Credentials
db_user='root'
db_password='1004'
db_host='localhost'
db_name='airport_db'

##Create Connection Engine
engine= create_engine(f'mysql+pymysql://{db_user}:{db_password}@{db_host}/{db_name}')

## Query Data
query= "SELECT * from airports2"
df= pd.read_sql(query,engine)
df.head()
# Out:
#   Origin_airport Destination_airport    Origin_city Destination_city  \
# 0            MHK                 AMW  Manhattan, KS         Ames, IA
# 1            EUG                 RDM     Eugene, OR         Bend, OR
# 2            EUG                 RDM     Eugene, OR         Bend, OR
# 3            EUG                 RDM     Eugene, OR         Bend, OR
# 4            MFR                 RDM    Medford, OR         Bend, OR
#
#    Passengers  Seats  Flights  Distance    Fly_date  Origin_population  \
# 0          21     30        1       254  2008-10-01             122049
# 1          41    396       22       103  1990-11-01             284093
# 2          88    342       19       103  1990-12-01             284093
# 3          11     72        4       103  1990-10-01             284093
# 4           0     18        1       156  1990-02-01             147300
#
#    Destination_population  Org_airport_lat  Org_airport_long Dest_airport_lat  \
# 0                   86219        39.140999        -96.670799               NA
# 1                   76034        44.124599       -123.211998       44.2541008
# 2                   76034        44.124599       -123.211998       44.2541008
# 3                   76034        44.124599       -123.211998       44.2541008
# 4                   76034        42.374199       -122.873001       44.2541008
#
#   Dest_airport_long
# 0                NA
# 1      -121.1500015
# 2      -121.1500015
# 3      -121.1500015
# 4      -121.1500015

# %%
## Create Simple Dash Application
from dash import Dash, dcc, html
import plotly.express as px

##Create Dash App
app= Dash(__name__)

##Plot using plotly (Passengers data over distance)
fig = px.scatter(df, x='Distance', y='Passengers', color='Origin_airport',
                 title='Passengers Vs Distance', labels={'Passengers':'Passengers','Distance':'Distance (Miles)'})

fig_bar = px.bar(df, x='Origin_airport',y='Seats',color='Destination_airport',
                 title='Seats per flight', labels={'Seats':'No of Seats','Origin_airport':'Origin Airport'})

app.layout = html.Div(children=[
    html.H1(children='Flight Dashboard'),
    dcc.Graph(
        id='passenger-distance-graph',
        figure=fig
    ),
    dcc.Graph(
        id='seats-bar-chart',
        figure=fig_bar
    ),
    html.Div(children='Dashboard for visualization of flight data')
])                 

if __name__=='__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from dash import dcc, html, Input, Output
import dash
import plotly.express as px
import pandas as pd

# Reuse the same data (df) from the previous code

# Create the Dash App
app = dash.Dash(__name__)

# Layout with Dropdown and DatePicker
app.layout = html.Div([
    html.H1("Flight Dashboard"),

    # Dropdown for selecting the Origin Airport
    dcc.Dropdown(
        id='origin-airport-dropdown',
        options=[{'label': airport, 'value': airport} for airport in df['Origin_airport'].unique()],
        placeholder="Select an Origin Airport",
        multi=True
    ),

    # Date range picker for Fly_date
    dcc.DatePickerRange(
        id='date-picker-range',
        start_date=df['Fly_date'].min(),
        end_date=df['Fly_date'].max(),
        display_format='YYYY-MM-DD'
    ),

    # Graph
    dcc.Graph(id='filtered-passenger-distance-graph'),
    
    dcc.Graph(id='filtered-seats-bar-chart')
])

# Callback for interactivity
@app.callback(
    [Output('filtered-passenger-distance-graph', 'figure'),
     Output('filtered-seats-bar-chart', 'figure')],
    [Input('origin-airport-dropdown', 'value'),
     Input('date-picker-range', 'start_date'),
     Input('date-picker-range', 'end_date')]
)
def update_graphs(selected_airports, start_date, end_date):
    # Filter data based on selected airports and date range
    filtered_df = df[(df['Fly_date'] >= start_date) & (df['Fly_date'] <= end_date)]
    if selected_airports:
        filtered_df = filtered_df[filtered_df['Origin_airport'].isin(selected_airports)]
    
    # Update scatter plot (Passengers vs Distance)
    scatter_fig = px.scatter(filtered_df, x='Distance', y='Passengers', color='Origin_airport',
                             title="Filtered Passengers vs Distance")

    # Update bar chart (Seats per Origin Airport)
    bar_fig = px.bar(filtered_df, x='Origin_airport', y='Seats', color='Destination_airport',
                     title="Filtered Seats per Flight")

    return scatter_fig, bar_fig

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
